# %%
import pandas as pd

locat = pd.read_csv('C:\College Task\Smt 5\OOP\Software_design\cities15000.csv')
cit_name = locat[locat['name']=='Bandung'].index.values[0]
print(locat)
lat = (locat.loc[cit_name,'latitude'])
abs_lat = abs(float(lat))
# Out:
#       geonameid              name         asciiname  \
# 0       3040051      les Escaldes      les Escaldes
# 1       3041563  Andorra la Vella  Andorra la Vella
# 2        290594    Umm al Qaywayn    Umm al Qaywayn
# 3        291074    Ras al-Khaimah    Ras al-Khaimah
# 4        291696     Khawr Fakk��n      Khawr Fakkan
# ...         ...               ...               ...
# 23464    894701          Bulawayo          Bulawayo
# 23465    895061           Bindura           Bindura
# 23466    895269        Beitbridge        Beitbridge
# 23467   1085510           Epworth           Epworth
# 23468   1106542       Chitungwiza       Chitungwiza
#
#                                           alternatenames   latitude longitude  \
# 0      Ehskal'des-Ehndzhordani,Escaldes,Escaldes-Engo...   42.50729   1.53414
# 1      ALV,Ando-la-Vyey,Andora,Andora la Vela,Andora ...   42.50779   1.52109
# 2      Oumm al Qaiwain,Oumm al Qa��wa��n,Um al Kawain...   25.56473  55.55517
# 3      Julfa,Khaimah,RKT,Ra's al Khaymah,Ra's al-Chai...   25.78953   55.9432
# 4      Fakkan,Fakk��n,Khawr Fakkan,Khawr Fakk��n,Khaw...   25.33132  56.34199
# ...                                                  ...        ...       ...
# 23464  BUQ,Bulavajas,Bulavajo,Bulavejo,Bulawayo,Gorad...     -20.15  28.58333
# 23465  Bindura,Bindura Town,Kimberley Reefs,_�_�___��...  -17.30192  31.33056
# 23466  Bajtbridz,Bajtbridzh,Beitbridge,Beitbridzas,Be...  -22.21667        30
# 23467                                            Epworth     -17.89   31.1475
# 23468  Chitungviza,Chitungwiza,Citungviza,Gorad Chytu...  -18.01274  31.07555
#
#       feature class feature code country code  cc2 admin1 code admin2 code  \
# 0                 P         PPLA           AD  NaN           8         NaN
# 1                 P         PPLC           AD  NaN           7         NaN
# 2                 P         PPLA           AE  NaN           7         NaN
# 3                 P         PPLA           AE  NaN           5         NaN
# 4                 P          PPL           AE  NaN           6         NaN
# ...             ...          ...          ...  ...         ...         ...
# 23464             P         PPLA           ZW  NaN           9         NaN
# 23465             P         PPLA           ZW  NaN           3         NaN
# 23466             P          PPL           ZW  NaN           7         NaN
# 23467             P         PPLX           ZW  NaN          10         NaN
# 23468             P          PPL           ZW  NaN          10         NaN
#
#       admin3 code admin4 code population elevation     dem        timezone  \
# 0             NaN         NaN      15853       NaN  1033.0  Europe/Andorra
# 1             NaN         NaN      20430       NaN  1037.0  Europe/Andorra
# 2             NaN         NaN      44411       NaN     2.0      Asia/Dubai
# 3             NaN         NaN     115949       NaN     2.0      Asia/Dubai
# 4             NaN         NaN      33575       NaN    20.0      Asia/Dubai
# ...           ...         ...        ...       ...     ...             ...
# 23464         NaN         NaN     699385       NaN  1348.0   Africa/Harare
# 23465         NaN         NaN      37423       NaN  1118.0   Africa/Harare
# 23466         NaN         NaN      26459       NaN   461.0   Africa/Harare
# 23467         NaN         NaN     123250       NaN  1508.0   Africa/Harare
# 23468         NaN         NaN     340360       NaN  1435.0   Africa/Harare
#
#       modification date
# 0              10/15/08
# 1               5/30/10
# 2               10/7/14
# 3               12/5/15
# 4              10/25/13
# ...                 ...
# 23464            8/3/10
# 23465            8/3/10
# 23466           3/12/13
# 23467           1/19/12
# 23468           1/20/12
#
# [23469 rows x 19 columns]

# %%
from solar_cell import *
from material import *
from mode import *
from spec import *
from position import *
import pandas as pd

####################################################################
##                        searching latitude                      ##
####################################################################
print ("####################################################################")
print ("##                          Latitude                              ##")
print ("####################################################################")
city_name = input("Input the city name: ")
locat = pd.read_csv('C:\College Task\Smt 5\OOP\software design final\cities15000.csv')
if city_name not in locat['name'].values:
    print ("Your city is not in our automated list")
    lat = float(input("Input the latitude: "))
else :
    cit_name = locat[locat['name']==city_name].index.values[0]
    lat = (locat.loc[cit_name,'latitude'])

abs_lat = abs(float(lat))
####################################################################

####################################################################
##                             Type                               ##
####################################################################
sw280 = Type (280,39.5,31.2,9.71,9.07,0.167)
sw285 = Type (285,39.7,31.3,9.84,9.20,0.17)
sw290 = Type (290,39.9,31.4,9.97,9.33,0.173)
sw295 = Type (295,40.0,31.5,10.10,9.45,0.1759)
####################################################################

####################################################################
##                            Material                            ##
####################################################################
Cu = Material(0,4.7)
Ag = Material(0,4.26)
Zn = Material (0,4.3) 
Si = Material (1.12,0)
Am_Si = Material(1.75,0)
CdTe = Material(1.5,0)
####################################################################

####################################################################
##                         Mode Selection                         ##
####################################################################
print ("####################################################################")
print ("##                          Mode                                  ##")
print ("####################################################################")
print("MODE:\n 0.STC : When the temperature lower or equal to 25\n 1.NOTC : When the temperature higher than 25")
a = int(input('Choose Mode (0/1): '))
if a == 0:
    n = Mode('STC')
elif a == 1:
    n = Mode('NOCT')
####################################################################

####################################################################
##                         Weather Selection                      ##
####################################################################
if abs_lat > 23.5 : 
    print("Weather:\n 0.SUMMER : APPLIED FOR SUMMER OR SPRING\n 1.WINTER : APPLIED FOR FALL AND WINTER")
    x = int(input('Choose Weather (0/1): '))
    if x == 0:
        weather = 'S'
    elif x == 1:
        weather = 'W'
elif abs_lat <= 23.5 :
    weather = "S"
####################################################################

####################################################################
##                          Controller                            ##
####################################################################
Power_input = 1000 #input the power counted from the sun
light_freq = 4.15*10**18 #input the light freq
width = float(input("Input your solar cell width in meter: ")) #input the width of solar cell (in meter)
length = float(input("Input your solar cell length in meter: ")) #input the length of solar cell (in meter)
start_hour = int(input("Input the start time (in 24 hours system) : ")) #input the start Hour (format 24 Hours)
stop_hour = int(input("Input the stop time (in 24 hours system) : ")) #input stop hour (format 24 Hours)
mode = n #0 for STC and 1 for NOCT
latitude = abs_lat #location latitude
material = Si
type_cell = sw280
Weather = weather #S for Summer, W for Winter
####################################################################

####################################################################
##                           Attr creation                        ##
####################################################################
area = Area(length,width)
operation_time = Operation_time(start_hour,stop_hour)
angle = Angle(latitude,Weather)
####################################################################

####################################################################
##                          Object Creation                       ##
####################################################################
solar_cell_1 = Solar_cell(angle.ideal_angle(),operation_time.op_time(),area.area(),material,type_cell,mode,Power_input,light_freq)
####################################################################

####################################################################
##                             OUTPUT                             ##
####################################################################
print("####################################################################")
print("##                             OUTPUT                             ##")
print("####################################################################")

print(f"Angle : {round(solar_cell_1.angle,2)} degree")
print(f"Operation Time : {solar_cell_1.operation_time} hours")
print(f"Area of Solar cell : {round(solar_cell_1.area,2)} sqm")
print(f"Solar Cell Operating Mode : {solar_cell_1.mode}")
min_freq = "{:e}".format(solar_cell_1.material.Min_frequency())
print(f"Minimum Frequency to activate the cell :{min_freq} Hz")
print(f"Solar Cell Power Output: {round(solar_cell_1.count_output(),2)} Watt")
print(f"Power Output in a Day : {round(solar_cell_1.Power_output_in_a_day(),2)} Wh")

# %%
from solar_cell import *
from material import *
from mode import *
from spec import *
from position import *
import pandas as pd

class Main :
    ####################################################################
    ##                             Type                               ##
    ####################################################################
    sw280 = Type (280,39.5,31.2,9.71,9.07,0.167)
    sw285 = Type (285,39.7,31.3,9.84,9.20,0.17)
    sw290 = Type (290,39.9,31.4,9.97,9.33,0.173)
    sw295 = Type (295,40.0,31.5,10.10,9.45,0.1759)
    ####################################################################

    ####################################################################
    ##                            Material                            ##
    ####################################################################
    Cu = Material(0,4.7)
    Ag = Material(0,4.26)
    Zn = Material (0,4.3) 
    Si = Material (1.12,0)
    Am_Si = Material(1.75,0)
    CdTe = Material(1.5,0)
    ####################################################################
    def __init__(self) -> None:
        pass

    def ask_param(self):
        print ("####################################################################")
        print ("##                          Latitude                              ##")
        print ("####################################################################")
        city_name = input("Input the city name: ")
        locat = pd.read_csv('C:\College Task\Smt 5\OOP\software design final\cities15000.csv')
        if city_name not in locat['name'].values:
            print ("Your city is not in our automated list")
            lat = float(input("Input the latitude: "))
        else :
            cit_name = locat[locat['name']==city_name].index.values[0]
            lat = (locat.loc[cit_name,'latitude'])

        abs_lat = abs(float(lat))
        print ("####################################################################")
        print ("##                          Mode                                  ##")
        print ("####################################################################")
        print("MODE:\n 0.STC : When the temperature lower or equal to 25\n 1.NOTC : When the temperature higher than 25")
        a = int(input('Choose Mode (0/1): '))
        if a == 0:
            n = Mode('STC')
        elif a == 1:
            n = Mode('NOCT')
        if abs_lat > 23.5 : 
            print("Weather:\n S : APPLIED FOR SUMMER OR SPRING\n W : APPLIED FOR FALL AND WINTER")
            x = input('Choose Weather (S/W): ')
            if x.upper() == 'S':
                weather = 'S'
            elif x.upper() == 'W':
                weather = 'W'
        elif abs_lat <= 23.5 :
            weather = "S"

        latitude = abs_lat #location latitude

        return weather,n,latitude

    def create_spec(self):
        self.ask_param()
        width = float(input("Input your solar cell width in meter: ")) #input the width of solar cell (in meter)
        length = float(input("Input your solar cell length in meter: ")) #input the length of solar cell (in meter)
        start_hour = int(input("Input the start time (in 24 hours system) : ")) #input the start Hour (format 24 Hours)
        stop_hour = int(input("Input the stop time (in 24 hours system) : ")) #input stop hour (format 24 Hours)
        area = Area(length,width)
        operation_time = Operation_time(start_hour,stop_hour)
        angle = Angle(latitude,weather)

        return area,operation_time,angle

    def output (self):
        self.create_spec()
        Power_input = 1000 #input the power counted from the sun
        light_freq = 4.15*10**18 #input the light freq
        mode = n #0 for STC and 1 for NOCT
        material = Main.Si
        type_cell = Main.sw280
        solar_cell_1 = Solar_cell(angle.ideal_angle(),operation_time.op_time(),area.area(),material,type_cell,mode,Power_input,light_freq)
        print("####################################################################")
        print("##                             OUTPUT                             ##")
        print("####################################################################")

        print(f"Angle : {round(solar_cell_1.angle,2)} degree")
        print(f"Operation Time : {solar_cell_1.operation_time} hours")
        print(f"Area of Solar cell : {round(solar_cell_1.area,2)} sqm")
        print(f"Solar Cell Operating Mode : {solar_cell_1.mode}")
        min_freq = "{:e}".format(solar_cell_1.material.Min_frequency())
        print(f"Minimum Frequency to activate the cell :{min_freq} Hz")
        print(f"Solar Cell Power Output: {round(solar_cell_1.count_output(),2)} Watt")
        print(f"Power Output in a Day : {round(solar_cell_1.Power_output_in_a_day(),2)} Wh")


    def Run (self):
        self.output()

main = Main()
main.Run()
# Out:
# ####################################################################
# ##                          Latitude                              ##
# ####################################################################
# ####################################################################
# ##                          Mode                                  ##
# ####################################################################
# MODE:
#  0.STC : When the temperature lower or equal to 25
#  1.NOTC : When the temperature higher than 25
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\College Task\Smt 5\OOP\software design final\loc.ipynb Cell 3' in <cell line: 106>()
#     <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=102'>103</a>         self.output()
#     <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=104'>105</a> main = Main()
# --> <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=105'>106</a> main.Run()
#
# c:\College Task\Smt 5\OOP\software design final\loc.ipynb Cell 3' in Main.Run(self)
#     <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=101'>102</a> def Run (self):
# --> <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=102'>103</a>     self.output()
#
# c:\College Task\Smt 5\OOP\software design final\loc.ipynb Cell 3' in Main.output(self)
#      <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=79'>80</a> def output (self):
# ---> <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=80'>81</a>     self.create_spec()
#      <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=81'>82</a>     Power_input = 1000 #input the power counted from the sun
#      <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=82'>83</a>     light_freq = 4.15*10**18 #input the light freq
#
# c:\College Task\Smt 5\OOP\software design final\loc.ipynb Cell 3' in Main.create_spec(self)
#      <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=73'>74</a> area = Area(length,width)
#      <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=74'>75</a> operation_time = Operation_time(start_hour,stop_hour)
# ---> <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=75'>76</a> angle = Angle(latitude,weather)
#      <a href='vscode-notebook-cell:/c%3A/College%20Task/Smt%205/OOP/software%20design%20final/loc.ipynb#ch0000003?line=77'>78</a> return area,operation_time,angle
#
# NameError: name 'latitude' is not defined

# %%
from solar_cell import *
from material import *
from mode import *
from spec import *
from position import *
import pandas as pd


class Main :
    ####################################################################
    ##                             Type                               ##
    ####################################################################
    sw280 = Type (280,39.5,31.2,9.71,9.07,0.167)
    sw285 = Type (285,39.7,31.3,9.84,9.20,0.17)
    sw290 = Type (290,39.9,31.4,9.97,9.33,0.173)
    sw295 = Type (295,40.0,31.5,10.10,9.45,0.1759)
    ####################################################################

    ####################################################################
    ##                            Material                            ##
    ####################################################################
    Cu = Material(0,4.7)
    Ag = Material(0,4.26)
    Zn = Material (0,4.3) 
    Si = Material (1.12,0)
    Am_Si = Material(1.75,0)
    CdTe = Material(1.5,0)
    ####################################################################
    def __init__(self) -> None:
        pass

    
    def calculate_latitude(self):
        print ("####################################################################")
        print ("##                          Latitude                              ##")
        print ("####################################################################")
        city_name = input("Input the city name: ")
        locat = pd.read_csv('C:\College Task\Smt 5\OOP\software design final\cities15000.csv')
        if city_name not in locat['name'].values:
            print ("Your city is not in our automated list")
            lat = float(input("Input the latitude: "))
        else :
            cit_name = locat[locat['name']==city_name].index.values[0]
            lat = (locat.loc[cit_name,'latitude'])

        abs_lat = abs(float(lat))
        return abs_lat

    def select_mode(self):
        print ("####################################################################")
        print ("##                          Mode                                  ##")
        print ("####################################################################")
        print ("MODE:\n 0.STC : When the temperature lower or equal to 25\n 1.NOTC : When the temperature higher than 25")
        a = int(input('Choose Mode (0/1): '))
        if a == 0:
            n = Mode('STC')
        elif a == 1:
            n = Mode('NOCT')

        return n


    def weather_selection(self,latitude):
        if latitude > 23.5 : 
            print("Weather:\n S : APPLIED FOR SUMMER OR SPRING\n W : APPLIED FOR FALL AND WINTER")
            x = input('Choose Weather (S/W): ')
            if x.upper() == 'S':
                weather = 'S'
            elif x.upper() == 'W':
                weather = 'W'
        elif latitude <= 23.5 :
            weather = "S"

        return weather


    def create_area(self):
        width = float(input("Input your solar cell width in meter: ")) #input the width of solar cell (in meter)
        length = float(input("Input your solar cell length in meter: ")) #input the length of solar cell (in meter)
        area = Area(length,width)

        return area


    def count_operation_time(self):
        start_hour = int(input("Input the start time (in 24 hours system) : ")) #input the start Hour (format 24 Hours)
        stop_hour = int(input("Input the stop time (in 24 hours system) : ")) #input stop hour (format 24 Hours)
        operation_time = Operation_time(start_hour,stop_hour)

        return operation_time

    def output(self):
        latitude = self.calculate_latitude()
        weather = self.weather_selection(latitude)
        mode = self.select_mode()
        area = self.create_area()
        operation_time= self.count_operation_time()
        angle = Angle(latitude,weather)
        Power_input = 1000 #input the power counted from the sun
        light_freq = 4.15*10**18 #input the light freq
        material = Main.Si
        type_cell = Main.sw280
        solar_cell_1 = Solar_cell(angle.ideal_angle(),operation_time.op_time(),area.area(),material,type_cell,mode,Power_input,light_freq)
        print("####################################################################")
        print("##                             OUTPUT                             ##")
        print("####################################################################")
        print(f"Angle : {round(solar_cell_1.angle,2)} degree")
        print(f"Operation Time : {solar_cell_1.operation_time} hours")
        print(f"Area of Solar cell : {round(solar_cell_1.area,2)} sqm")
        print(f"Solar Cell Operating Mode : {solar_cell_1.mode}")
        min_freq = "{:e}".format(solar_cell_1.material.Min_frequency())
        print(f"Minimum Frequency to activate the cell :{min_freq} Hz")
        print(f"Solar Cell Power Output: {round(solar_cell_1.count_output(),2)} Watt")
        print(f"Power Output in a Day : {round(solar_cell_1.Power_output_in_a_day(),2)} Wh")
        
    def Run(self):
        self.output()

main = Main()
main.Run()
# Out:
# ####################################################################
# ##                          Latitude                              ##
# ####################################################################
# ####################################################################
# ##                          Mode                                  ##
# ####################################################################
# MODE:
#  0.STC : When the temperature lower or equal to 25
#  1.NOTC : When the temperature higher than 25
# ####################################################################
# ##                             OUTPUT                             ##
# ####################################################################
# Angle : 45.0 degree
# Operation Time : 2 hours
# Area of Solar cell : 0.12 sqm
# Solar Cell Operating Mode : STC
# Minimum Frequency to activate the cell :2.708148e+14 Hz
# Solar Cell Power Output: 20.04 Watt
# Power Output in a Day : 40.08 Wh
